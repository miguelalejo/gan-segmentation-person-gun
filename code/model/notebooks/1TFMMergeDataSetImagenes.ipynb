# %% [markdown]
# ---
# * **Universidad:** UOC (Universitat Oberta de Catalunya)
# * **Titulación:** Master Ciencia de Datos/TFM
# * **Título:** Segmentación de imágenes utilizando Redes Generativas Antagónicas
# * **Actividad**: Creación Conjuntos Datos Detección de Armas
# * **Autor:** Miguel Ponce
# * **Correo:** miguelalejoponce@uoc.edu
# * **Fecha:** "Noviembre, 25 de 2022"
# * **Salida**: ipynb
# ---
# ## Contexto: Preprocesamiento Datos
#
# * **Contexto:**
# Seleccionar conjuntos de imagenes para la detección de personas y armas
# * **Problema:**
# Existen diferentes conjuntos de datos disponibles sin embargo se ha seleccionado aquellos que puedan brindar un mejor resultado para la detección de armas cortas.
#
# * **Solucion :**
# Se tomaran diferentes proyectos de Roboflow herramienta utilizada para la creación de conjuntos de datos en la nube y etiquetamiento de imagenes. Se crea un nuevo repositorio en Roboflow con las imagenes.
# * **Entorno:** Sin GPU.
#
#
# ## Origen del la fuente de datos
# @misc{ gun-detection-cctv_dataset,
#     title = { gun detection cctv Dataset },
#     type = { Open Source Dataset },
#     author = { sc19sjjd@leeds.ac.uk },
#     howpublished = { \url{ https://universe.roboflow.com/sc19sjjd-leeds-ac-uk/gun-detection-cctv } },
#     url = { https://universe.roboflow.com/sc19sjjd-leeds-ac-uk/gun-detection-cctv },
#     journal = { Roboflow Universe },
#     publisher = { Roboflow },
#     year = { 2022 },
#     month = { apr },
#     note = { visited on 2022-11-25 },
# }
#
# ```
#
# Nota: Los datos proporcionados en este desafío son ficticios y no se corresponden con la realidad de ninguna manera.

# %% [markdown]
# ## Instalar requisitos

# %%
# !python -m pip install roboflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 42 kB 323 kB/s
# ...
#      |████████████████████████████████| 138 kB 6.7 MB/s
# ...
#      |████████████████████████████████| 67 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 54 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 145 kB 8.0 MB/s
# ...
#      |████████████████████████████████| 178 kB 7.7 MB/s
# ...
#      |████████████████████████████████| 62 kB 840 kB/s
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=3b1db2a90dd4edca6579e426fb9241e679facdaeefc974b3e9e83177a932faa6
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: certifi
# ...

# %% [markdown]
# ## Importar Librerias

# %%
from roboflow import Roboflow

# %% [markdown]
# ## Descargar Conjuntos de Datos

# %% [markdown]
# @misc{ gunman2_dataset,
#     title = {  gunman2 Dataset },
#     type = { Open Source Dataset },
#     author = { personal work },
#     howpublished = { \url{ https://universe.roboflow.com/personal-work-atipa/gunman2 } },
#     url = { https://universe.roboflow.com/personal-work-atipa/gunman2 },
#     journal = { Roboflow Universe },
#     publisher = { Roboflow },
#     year = { 2022 },
#     month = { may },
#     note = { visited on 2022-12-13 },
# }

# %%
rf = Roboflow(api_key="3rOW8xY5g1wv0JEQF2Vl")
project = rf.workspace("personal-work-atipa").project("gunman2")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to -gunman2-1 in yolov5pytorch:: 100%|██████████| 312/312 [00:00<00:00, 1681.33it/s]

# %% [markdown]
# @misc{ gun-detection-cctv-br07f_dataset,
#     title = { Gun Detection CCTV Dataset },
#     type = { Open Source Dataset },
#     author = { sc19sjjd@leeds.ac.uk },
#     howpublished = { \url{ https://universe.roboflow.com/sc19sjjd-leeds-ac-uk/gun-detection-cctv-br07f } },
#     url = { https://universe.roboflow.com/sc19sjjd-leeds-ac-uk/gun-detection-cctv-br07f },
#     journal = { Roboflow Universe },
#     publisher = { Roboflow },
#     year = { 2022 },
#     month = { apr },
#     note = { visited on 2022-12-13 },
# }

# %%
rf = Roboflow(api_key="3rOW8xY5g1wv0JEQF2Vl")
project = rf.workspace("abhishekparth").project("pistol-y5ku1")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to pistol-1 in yolov5pytorch:: 100%|██████████| 916/916 [00:00<00:00, 927.31it/s]

# %% [markdown]
# @misc{ pistol-y5ku1_dataset,
#     title = { pistol Dataset },
#     type = { Open Source Dataset },
#     author = { AbhishekParth },
#     howpublished = { \url{ https://universe.roboflow.com/abhishekparth/pistol-y5ku1 } },
#     url = { https://universe.roboflow.com/abhishekparth/pistol-y5ku1 },
#     journal = { Roboflow Universe },
#     publisher = { Roboflow },
#     year = { 2022 },
#     month = { jan },
#     note = { visited on 2022-12-13 },
# }

# %%
rf = Roboflow(api_key="3rOW8xY5g1wv0JEQF2Vl")
project = rf.workspace("sc19sjjd-leeds-ac-uk").project("gun-detection-cctv")
dataset = project.version(8).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to gun-detection-cctv-8 in yolov5pytorch:: 100%|██████████| 8920/8920 [00:04<00:00, 2191.84it/s]

# %% [markdown]
# ## Merge Conjuntos de Datos

# %%
# !rm -rf gun-detection-ori 
# !mkdir gun-detection-ori

# %%
# !cp -r ./-gunman2-1/* ./gun-detection-ori
# !cp -r ./gun-detection-cctv-8/* ./gun-detection-ori
# !cp -r ./pistol-1/* ./gun-detection-ori

# %%
# !tar -czvf gun-detection-ori.tar.gz "./gun-detection-ori"
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# ./gun-detection-ori/train/images/mgd_custom_frame519_jpg.rf.3a707d3f21c1a13a2b81c7bdfcc7147e.jpg
# ./gun-detection-ori/train/images/mgd_custom_frame2475_jpg.rf.cb919331de570558004b2aa6ba5aaa26.jpg
# ./gun-detection-ori/train/images/gmd_2_frame34_jpg.rf.c9d5f85b7c8ad0f74be7becf028f42ec.jpg
# ./gun-detection-ori/train/images/mgd_custom_frame1670_jpg.rf.c71c27a62ab5e32ca685f130409be81c.jpg
# ./gun-detection-ori/train/images/mgd_custom_frame11_jpg.rf.aff41f6f631c205b7d2c8fd663ff4740.jpg
# ./gun-detection-ori/train/images/mgd_custom_frame634_jpg.rf.a16fd8447ef6d1d029ed41e87aae48c1.jpg
# ./gun-detection-ori/train/images/gmd_3_frame55_jpg.rf.0702413eed42ac2f3ee3278311041054.jpg
# ./gun-detection-ori/train/images/mgd_custom_frame1650_jpg.rf.c464a8eef080c1223bb9037d2839973c.jpg
# ./gun-detection-ori/train/images/mgd_custom_frame1847_jpg.rf.8927d0abcbfb8874191532e49356cc0c.jpg
# ...

# %% [markdown]
# ## Montar Drive

# %%
import os
from google.colab import drive
ROOT_FOLDER='/content/'
ROOT_DRIVE_FOLDER=ROOT_FOLDER+'drive/'
drive.mount(ROOT_DRIVE_FOLDER)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Cargar en Drive

# %%
# !cp --suffix=_v_$(date +"%y-%m-%d--%T")  ./gun-detection-ori.tar.gz /content/drive/MyDrive/tmf-person-data/data_set_processed/data-set-guns
